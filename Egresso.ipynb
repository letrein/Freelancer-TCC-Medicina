# %%
import pandas as pd


# Leitura do arquivo CSV com tratamento de erros
df = pd.read_csv("G:/Meu Drive/Nilce/Egresso/EGRESSO_UNIDO_FAC.csv", 
                 sep=';', encoding='utf-8')  

# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#          Sexo    idade estado_civil filhos  semestre_conclusao  \
# 0  Masculino        27     Solteiro    Nao             Segundo
# 1   Masculino       35     Solteiro    Não    Segundo semestre
# 2   Feminino        26    Solteira    Não    Me formei em 2023
# 3   Feminino   27 anos     Solteira   Não   1 semestre de 2020
# 4   Feminino   31 anos    Solteira    Não                 2019
#
#   associacao_sindicato                 ocupacao atuacao_area_formacao  \
# 0                  Sim  trabalhando e estudando       sim, totalmente
# 1                  Não              trabalhando                   não
# 2                  Não              trabalhando                   não
# 3                  Não              trabalhando       sim, totalmente
# 4                  Não              trabalhando       sim, totalmente
#
#                    vinculo_emprego  n_locais_emprego  ...  \
# 0                     Proprietário                 1  ...
# ...

# %% [markdown]
# Arrumando coluna 'Sexo'

# %%
df['Sexo'].unique()
# Out:
# array(['Masculino ', 'Masculino', 'Feminino ', 'Feminino', 'Homem', 'F',
#        'Feminink', 'Femenino ', 'f', 'Fermino '], dtype=object)

# %%
df['Sexo'] = df['Sexo'].replace(['Masculino ', 'Masculino','Homem'], 'Masculino')
df['Sexo'] = df['Sexo'].replace(['Feminino ', 'Feminino','F','Feminink','Femenino ','f','Fermino '], 'Feminino')

# %%
df['Sexo'].unique()
# Out:
# array(['Masculino', 'Feminino'], dtype=object)

# %% [markdown]
# Arrumando coluna "idade"

# %%
df['idade'].unique()
# Out:
# array(['27', '35', '26', '27 anos', '31 anos', '33', '29', '38', '43',
#        '25', '36 anos ', '31', '57', '40', '34', '39', '32', '24', '28',
#        '34 anos ', '30', '41', '46', '42', '23', '53', '45', '23 anos',
#        '24 anos', '50', '49', '36'], dtype=object)

# %%
df['idade'] = df['idade'].replace(['27 anos'], '27')
df['idade'] = df['idade'].replace(['31 anos'], '31')
df['idade'] = df['idade'].replace(['36 anos '], '36')
df['idade'] = df['idade'].replace(['34 anos '], '34')
df['idade'] = df['idade'].replace(['23 anos'], '23')
df['idade'] = df['idade'].replace(['24 anos'], '24')

# %%
df['idade'].unique()
# Out:
# array(['27', '35', '26', '31', '33', '29', '38', '43', '25', '36', '57',
#        '40', '34', '39', '32', '24', '28', '30', '41', '46', '42', '23',
#        '53', '45', '50', '49'], dtype=object)

# %% [markdown]
# arrumando coluna "estado_civil"

# %%
df['estado_civil'].unique()
# Out:
# array(['Solteiro', 'Solteira ', 'Solteira', 'Casada', 'Casado', 'Casada ',
#        'Solteiro ', 'Casado ', 'Divorciada', 'União estável ',
#        'Solteira \n', 'casada', 'divorciada', 'Viúva ', 'Cansada '],
#       dtype=object)

# %%
df['estado_civil'] = df['estado_civil'].replace(['Solteira ','Solteira','Solteiro ','Solteira \n'], 'Solteiro')
df['estado_civil'] = df['estado_civil'].replace(['Casada ','Casada','Casado ','casada','Cansada '], 'Casado')
df['estado_civil'] = df['estado_civil'].replace(['Divorciada','divorciada'], 'Divorciado')
df['estado_civil'] = df['estado_civil'].replace(['Viúva '], 'Viúvo')
df['estado_civil'] = df['estado_civil'].replace(['União estável '], 'União estável')

# %%
df['estado_civil'].unique()
# Out:
# array(['Solteiro', 'Casado', 'Divorciado', 'União estável', 'Viúvo'],
#       dtype=object)

# %% [markdown]
# arrumar coluna 'filhos'

# %%
df['filhos'].unique()
# Out:
# array(['Nao', 'Não', 'Não ', 'Sim', '1', 'Sim. 01', 'Nao ', 'Sim 1 ',
#        'Sim, 2 filhas ', 'Sim, duas ', 'Sim, 1.', '2', 'Sim 1', '1 filho',
#        'Sim, 1 filha', '3', 'Sim ', 'Sim, 3 ', 'sim, gestante. ', 'sim',
#        '5'], dtype=object)

# %%
df['filhos'] = df['filhos'].replace(['Nao','Não ','Nao ','Não'], '0')
df['filhos'] = df['filhos'].replace(['Sim ','Sim','Sim. 01','Sim 1 ','Sim, 1.','Sim 1','1 filho','Sim, 1 filha','Sim ','sim, gestante. ','sim'], '1')
df['filhos'] = df['filhos'].replace(['Sim, 2 filhas ','Sim, duas '], '2')
df['filhos'] = df['filhos'].replace(['Sim, 3 '] , '3')

# %%
df['filhos'].unique()
# Out:
# array(['0', '1', '2', '3', '5'], dtype=object)

# %% [markdown]
# arrumando coluna "semestre_conclusao"

# %%
df['semestre_conclusao'].unique()
# Out:
# array(['Segundo', 'Segundo semestre', 'Me formei em 2023',
#        '1 semestre de 2020', '2019', '2020', 'dez/23', '8',
#        '2 semestre/2023', 'fev/22', 'Segundo ', 'Dezembro de 2023',
#        'jun/24', '2022', '1 semestre de 2024', '1º', 'jan/24',
#        '2° de 2023\n', '8° semestre ', '1 semestre ', '02/07/2024',
#        '2 semestre de 2020', 'Primeiro semestre de 2023 ',
#        '1° semestre de 2021', 'Dezembro de 2023.', '08 2024', 'Gradruada',
#        'jul/23', '2023', 'dez/20', '2021', '1º 2022',
#        '8 semestre (4 anos) ', '2°/2023', 'jul/22', '2024 conclusão ',
#        'Primeiro ', '8°', 'Segundo semestre de 2023', '2 semestre 2020',
#        'Cursando', 'jan/22', 'Me formei em 2022', 'Formada ',
#        'Ensino superior ', '2 semestre 2022'], dtype=object)

# %%
df['semestre_conclusao'] = df['semestre_conclusao'].replace(['Segundo','Segundo semestre','Me formei em 2023','2019', '2020', 'dez/23', '8',
       '2 semestre/2023','Segundo ', 'Dezembro de 2023','2022', '2° de 2023\n','8° semestre ','2 semestre de 2020',
       'Dezembro de 2023.', '08 2024', 'Gradruada','2023', 'dez/20', '2021','8 semestre (4 anos) ', '2°/2023',
       '2024 conclusão ','8°', 'Segundo semestre de 2023', '2 semestre 2020', 'Cursando','Me formei em 2022', 'Formada ',
       'Ensino superior ', '2 semestre 2022'], 'Segundo semestre')
df['semestre_conclusao'] = df['semestre_conclusao'].replace(['1 semestre de 2020','fev/22','jun/24', '1 semestre de 2024', '1º', 'jan/24','1 semestre ', '02/07/2024',
                                                             'Primeiro semestre de 2023 ','1° semestre de 2021', 'jul/23', '1º 2022','jul/22','Primeiro ','jan/22'], 'Primeiro semestre')

# %%
df['semestre_conclusao'].unique()
# Out:
# array(['Segundo semestre', 'Primeiro semestre'], dtype=object)

# %% [markdown]
# Avaliação colunas

# %%
df['associacao_sindicato'].unique()
# Out:
# array(['Sim', 'Não'], dtype=object)

# %%
df['ocupacao'].unique()
# Out:
# array(['trabalhando e estudando', 'trabalhando',
#        'nem trabalhando, nem estudando', 'estudando'], dtype=object)

# %%
df['atuacao_area_formacao'].unique()
# Out:
# array(['sim, totalmente', 'não', 'sim, parcialmente'], dtype=object)

# %% [markdown]
# arrumando 'vinculo_empregado"

# %%
df['vinculo_emprego'].unique()
# Out:
# array(['Proprietário', 'Empregado com carteira assinada',
#        'Autônomo /prestador de serviço', 'Funcionário público concursado',
#        'Residente ', 'No momento não tenho ',
#        'Residente em farmácia pelo município de SJP', 'CLT e autonomo'],
#       dtype=object)

# %%
df['vinculo_emprego'] = df['vinculo_emprego'].replace([ 'Residente ','Residente em farmácia pelo município de SJP'], 'Residencia')
df['vinculo_emprego'] = df['vinculo_emprego'].replace(['No momento não tenho '] , 'Desempregado')
df['vinculo_emprego'] = df['vinculo_emprego'].replace(['Empregado com carteira assinada','CLT e autonomo'] , 'CLT')
df['vinculo_emprego'] = df['vinculo_emprego'].replace(['Funcionário público concursado'] , 'Funcionário público')
df['vinculo_emprego'] = df['vinculo_emprego'].replace([ 'Autônomo /prestador de serviço'] , 'Autônomo')

# %%
df['vinculo_emprego'].unique()
# Out:
# array(['Proprietário', 'CLT', 'Autônomo', 'Funcionário público',
#        'Residencia', 'Desempregado'], dtype=object)

# %%
df['n_locais_emprego'].unique()
# Out:
# array([1, 2])

# %%
df['local_atuacao'].unique()
# Out:
# array(['Clinica', 'Loja', 'Escrito ', 'Clínica de depilação a laser ',
#        'Consultorio', 'Domiciliar ',
#        'Hospital e Maternidade Nossa Senhora Aparecida ',
#        'Domiciliar ESF', 'Hospital', 'Hospital ',
#        'Escola e secretaria municipal de saúde ', 'Hospital do Rocio ',
#        'Hospital é escola ', 'Nenhuma...', 'Farmácia dispensação ',
#        'Farmácia ', 'Farmácia física ', 'farmácia ', 'Escritório',
#        'Consultório e Escritório ', 'Dispensação ',
#        'Hospital o último emprego ', 'Escritório ', 'Farmácia comercial ',
#        'Dental ', 'Consultório de estética ', 'Farmácia de Dispensação ',
#        'Farmácia Nissei', 'GrupoBoticario', 'Farmacia / comércio ',
#        'Farmacia ', 'Unidade Básica de Saúde ',
#        'Farmácia de dispensação ',
#        'Prefeitura de Rio Branco do Sul e Hospital de Clinicas ',
#        'Farmácia privada', 'Farmacia', 'Universidade ',
#        'Farmácia comunitária ', 'Drogaria', 'Farmácia',
# ...

# %%
df['local_atuacao'] = df['local_atuacao'].replace(['Escrito ','Escritório e domiciliar ','Dental ','Escritório '] , 'Escritório')
df['local_atuacao'] = df['local_atuacao'].replace(['Clínica de depilação a laser ','Clinica','Dental '], 'Clínica')
df['local_atuacao'] = df['local_atuacao'].replace(['Hospital e Maternidade Nossa Senhora Aparecida ','Hospital ','Hospital do Rocio ','Hospital é escola ', 'Hospital o último emprego ',
                                                    'Hospital e Distribuidora '], 'Hospital')
df['local_atuacao'] = df['local_atuacao'].replace(['Domiciliar ', 'Domiciliar ESF'], 'Domiciliar')
df['local_atuacao'] = df['local_atuacao'].replace(['Farmácia dispensação ', 'Farmácia ', 'Farmácia física ', 'farmácia ', 'Dispensação ','Farmácia comercial ',
                                                   'Farmácia de Dispensação ','Farmácia Nissei', 'Farmacia / comércio ','Farmacia ','Farmácia de dispensação ', 'Farmácia comunitária ', 
                                                   'Drogaria', 'Farmácia','Farmacia','Farmácia e consultório ','Farmácia privada'], 'Farmácia')
df['local_atuacao'] = df['local_atuacao'].replace(['consultorio','Consultório, escola','Consultorio', 'Consultório e Escritório ','Consultório de estética '] , 'Consultório')
df['local_atuacao'] = df['local_atuacao'].replace(['Escola e secretaria municipal de saúde ','Unidade Básica de Saúde ','Prefeitura de Rio Branco do Sul e Hospital de Clinicas '], 'SUS')
df['local_atuacao'] = df['local_atuacao'].replace([ 'GrupoBoticario'], 'Industria')
df['local_atuacao'] = df['local_atuacao'].replace(['Universidade '], 'Universidade')
df['local_atuacao'] = df['local_atuacao'].replace(['Restaurante '], 'Restaurante')  
df['local_atuacao'] = df['local_atuacao'].replace(['Universidade ','Universidade'], 'Educação' )
df['local_atuacao'] = df['local_atuacao'].replace(['Nenhuma...'], 'Desempregado')
df['local_atuacao'] = df['local_atuacao'].replace(['Setor qualidade uan','Merenda escola uan' ], 'Unidade de Alimentação e Nutrição')
df['local_atuacao'] = df['local_atuacao'].replace(['Unidade de Alimentação e Nutrição '], 'UAN ')

# %%
df['local_atuacao'].unique()
# Out:
# array(['Clínica', 'Loja', 'Escritório', 'Consultório', 'Domiciliar',
#        'Hospital', 'SUS', 'Desempregado', 'Farmácia', 'Industria',
#        'Educação', 'Restaurante', 'Unidade de Alimentação e Nutrição'],
#       dtype=object)

# %% [markdown]
# avaliação proximas colunas

# %%
df['area_atuacao'].unique()
# Out:
# array(['Estetica', 'Assistênte comercial', 'Assessora e produtora ',
#        'Consultora técnica/ treinamento de novas aplicadoras',
#        'Estética avançada ',
#        'Trabalho com estética através das redes sociais e também com marketing de afiliados ',
#        'Enfermeira centro cirúrgico ', 'Atendimento domiciliar saúde ',
#        'Enfermeiro', 'Pediatria ', 'Enfermeiro residente ',
#        'Unidade de terapia intensiva ', 'Enfermeiro e professor ',
#        'Não estou atuando, não dão chance para quem está iniciando. Fiz a faculdade, não trabalhava na área.',
#        'Farmacêutica Hospitalar ', 'Farmácia ', 'Gerência ',
#        'Farmacêutico dispensação ', 'Dispensação', 'Administrativo',
#        'Farmacêutica na SCIEH do Hospital do Rocio e Servidora Pública na Farmácia especial de Campo Largo',
#        'Hospitalar ',
#        'Farmacêutico responsável técnico e farmacêutico comercial ',
#        'FARMACÊUTICO ', 'Responsável técnica ', 'Estética ', 'Varejo',
# ...

# %%
df['area_atuacao'] = df['area_atuacao'].replace(['Estetica', 'Estética avançada ',
       'Trabalho com estética através das redes sociais e também com marketing de afiliados ','Estética '] , 'Estética')
df['area_atuacao'] = df['area_atuacao'].replace(['Assistênte comercial','Gerência ','Varejo','Compras matérias-primas.',], 'Comércio e Varejo')
df['area_atuacao'] = df['area_atuacao'].replace(['Farmacêutica Hospitalar ', 'Farmácia ', 'Farmacêutico dispensação ', 'Dispensação',
                                                'Farmacêutica na SCIEH do Hospital do Rocio e Servidora Pública na Farmácia especial de Campo Largo',
                                                'Farmacêutico responsável técnico e farmacêutico comercial ','FARMACÊUTICO ', 'Farmacêutico ','Farmacêutica ',
                                                'Dispensação de medicamentos ', 'Farmacêutica Residente ','Farmácia. Âmbito comercial', 'Dispensação ',
                                                'Gerente farmacêutico ', 'Farmacêutica responsável ','Manipulação '] , 'Farmácia')
df['area_atuacao'] = df['area_atuacao'].replace([ 'Enfermeira centro cirúrgico ', 'Atendimento domiciliar saúde ','Enfermeiro', 
                                                 'Enfermeiro residente ', 'Enfermeiro e professor '] , 'Enfermagem')
df['area_atuacao'] = df['area_atuacao'].replace(['Unidade de terapia intensiva ','Hospitalar ', 'Clincia e Planejamento ','Pediatria '] , 'Hospitalar')
df['area_atuacao'] = df['area_atuacao'].replace(['Nutrição na saúde da mulher e fertilidade ', 'Nutricionista de produção ', 'Uan', 'Uan ', 'nutricao'] , 'Nutrição')
df['area_atuacao'] = df['area_atuacao'].replace(['Responsável técnica ', 'Técnico Laboratório ','Consultora técnica/ treinamento de novas aplicadoras'], 'Laboratorial')
df['area_atuacao'] = df['area_atuacao'].replace(['Não estou atuando, não dão chance para quem está iniciando. Fiz a faculdade, não trabalhava na área.'], 'Desempregado')
df['area_atuacao'] = df['area_atuacao'].replace(['Assessora e produtora '] , 'Assessoria')
df['area_atuacao'] = df['area_atuacao'].replace(['Docente ensino superior '], 'Educação')

# %%
df['jornada_trabalho'].unique()
# Out:
# array(['8 horas', 'De 8 a 12 horas ', 'Variável ', '12x36', '6 horas',
#        '36horas/semanais em cada hospital', 'dez/36', '12', '12 horas ',
#        '4 horas', '44', '12h', '11h', '10h',
#        'Sou intermediário daí tenho um horário diferenciado.', '10 horas',
#        '07:20', '12 horas noturna  8 horas dia', '7h20',
#        '10 horas diárias (com 1 hora de intervalo)',
#        'Na área de nutrição trabalho poucas horas por mês '], dtype=object)

# %%
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['8 horas','De 8 a 12 horas ', '44','07:20', '7h20'],'8')
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['12x36','dez/36','12 horas ', '12h','12 horas noturna  8 horas dia',],'12')
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['6 horas', '36horas/semanais em cada hospital','Variável '],'6')
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['4 horas','Na área de nutrição trabalho poucas horas por mês '],'4')
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['Variável ', 'Sou intermediário daí tenho um horário diferenciado.','10 horas', '10 horas diárias (com 1 hora de intervalo)', '11h', '10h'],'10')

# %%
df['grau_sat_rendimento_bruto'].fillna('Não informado', inplace=True)
# Out:
# C:\Users\FOKO\AppData\Local\Temp\ipykernel_17276\2572496268.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['grau_sat_rendimento_bruto'].fillna('Não informado', inplace=True)

# %%
df['grau_sat_rendimento_bruto'].unique()
# Out:
# array(['mais de 8 salários mínimos', '2 salários mínimos',
#        '3 salários mínimos', '4 salários mínimos', '8 salários mínimos',
#        '5 salários mínimos', 'Não informado', '6 salários mínimos',
#        '7 salários mínimos', '\xa01 salário mínimo'], dtype=object)

# %%
df['grau_sat_rendimento_bruto'] = df['grau_sat_rendimento_bruto'].replace(['\xa01 salário mínimo', 'Não informado','2 salários mínimos'], 'até 2 salários mínimos')
df['grau_sat_rendimento_bruto'] = df['grau_sat_rendimento_bruto'].replace([ 'mais de 8 salários mínimos'], '8 salários mínimos ou mais')

# %%
df['grau_sat_trabalho'].unique()
# Out:
# array(['Muito satisfeito', 'Parcialmente satisfeito',
#        'Gostaria de mudar de atividade profissional'], dtype=object)

# %%
df['obtencao_primeiro_emprego'].unique()
# Out:
# array(['Estágio extra curricular', 'Concurso', 'Apresentação curricular',
#        'Indicação', 'Determinação pessoal', 'Já está a na área a 7anos',
#        'Proprietária ', 'Autônoma ', 'Promoção '], dtype=object)

# %%
df['obtencao_primeiro_emprego'] = df['obtencao_primeiro_emprego'].replace(['Já está a na área a 7anos'], 'Já atuava na área')

# %%
df['dificuldade_primeiro_emprego'].unique()
# Out:
# array(['Relações interpessoais', 'Não houve dificuldade',
#        ' Encontrar emprego com salário compatível',
#        'Dificuldade para formação de sua clientela', 'Experiência ',
#        'Hospital que aceite recém formado, sem experiência.',
#        'Processo seletivo ', 'Falta de experiência profissional',
#        'Normalmente procuram com experiência no cargo.', 'Oportunidade ',
#        'A maioria perder experiência e não dão oportunidade '],
#       dtype=object)

# %%
df['dificuldade_primeiro_emprego'] = df['dificuldade_primeiro_emprego'].replace(['Experiência ','Hospital que aceite recém formado, sem experiência.','Falta de experiência profissional',
                                                                                  'Normalmente procuram com experiência no cargo.', 'A maioria perder experiência e não dão oportunidade '], 'Falta de experiência')
df['dificuldade_primeiro_emprego'] = df['dificuldade_primeiro_emprego'].replace([ ' Encontrar emprego com salário compatível'], 'Salário baixo')
df['dificuldade_primeiro_emprego'] = df['dificuldade_primeiro_emprego'].replace(['Oportunidade ', 'Dificuldade para formação de sua clientela'], 'Falta de Oportunidades')
df['dificuldade_primeiro_emprego'] = df['dificuldade_primeiro_emprego'].replace([ 'Processo seletivo '], 'Passar em Processos seletivos')

# %%
df['atribuicao_dificuldade_primeiro_emprego'].unique()
# Out:
# array(['Falta de reconhecimento da profissão por outros profissionais ',
#        'Falta de reconhecimento da profissão pela sociedade',
#        'Experiência ',
#        'Não era meu primeiro emprego, mas foi o primeiro na área da enfermagem, mas não consegui como enfermeiro ',
#        'Falta de empenho pessoal durante a graduação', '.',
#        'Restrição do mercado de trabalho', 'Nenhuma',
#        'Formação insatisfatória por parte da faculdade',
#        'Falta de capacitação científica', 'Não tive dificuldades ',
#        'Muitos pedem experiência. ', 'Não tive', 'Nao houve', 'Não houve',
#        'Não houve dificuldade ', 'Eu não possuía tanta prática na área. ',
#        'Não tive dificuldade '], dtype=object)

# %%
df['atribuicao_dificuldade_primeiro_emprego'] = df['atribuicao_dificuldade_primeiro_emprego'].replace(['Falta de reconhecimento da profissão por outros profissionais ',
       'Falta de reconhecimento da profissão pela sociedade'], 'Falta de reconhecimento da profissão')
df['atribuicao_dificuldade_primeiro_emprego'] = df['atribuicao_dificuldade_primeiro_emprego'].replace(['Experiência ','Muitos pedem experiência. ',
                                                                                                       'Eu não possuía tanta prática na área. '], 'Falta de experiência')
df['atribuicao_dificuldade_primeiro_emprego'] = df['atribuicao_dificuldade_primeiro_emprego'].replace([ 'Nenhuma','Não tive dificuldades ', 'Não tive', 
                                                                                                       'Nao houve', 'Não houve', 'Não houve dificuldade ', 
                                                                                                       'Não tive dificuldade ','.'], 'Nenhuma Dificuldade')
df['atribuicao_dificuldade_primeiro_emprego'] = df['atribuicao_dificuldade_primeiro_emprego'].replace([ 'Não era meu primeiro emprego, mas foi o primeiro na área da enfermagem, mas não consegui como enfermeiro ',
                                                                                                       'Restrição do mercado de trabalho'], 'Falta de Oportunidades')
df['atribuicao_dificuldade_primeiro_emprego'] = df['atribuicao_dificuldade_primeiro_emprego'].replace([ 'Falta de empenho pessoal durante a graduação',
                                                                                                       'Formação insatisfatória por parte da faculdade',
                                                                                                       'Falta de capacitação científica'], 'Formação Insatisfatória')

# %%
df['tempo_para_colocao_mercado'].unique()
# Out:
# array(['Imediata', '\xa0até\xa0 6 meses', 'até um ano',
#        'de dois anos a cinco', 'de uma ano a dois',
#        'Após a faculdade, foi imediato, pois passei em vários concursos.',
#        '4 meses', 'Foi o tempo do meu desenvolvimento '], dtype=object)

# %%
df['tempo_para_colocao_mercado'] = df['tempo_para_colocao_mercado'].replace(['\xa0até\xa0 6 meses','4 meses'], 'Até 6 meses')
df['tempo_para_colocao_mercado'] = df['tempo_para_colocao_mercado'].replace(['até um ano'], 'Até 1 ano')
df['tempo_para_colocao_mercado'] = df['tempo_para_colocao_mercado'].replace(['de uma ano a dois','Foi o tempo do meu desenvolvimento ','de dois anos a cinco','Acima de 1 anos'], 'Acima de 1 ano')
df['tempo_para_colocao_mercado'] = df['tempo_para_colocao_mercado'].replace(['Imediata', 'Após a faculdade, foi imediato, pois passei em vários concursos.'], 'Imediato')

# %%
df[ 'formacao_continuada'].unique()
# Out:
# array(['Especialização', 'Nenhum', 'Não ',
#        'Aperfeiçoamento/Aprimoramento/ Capacitação', 'Residência',
#        'Não estou estudando', 'Pós-graduação em oncologia ',
#        'Cursos livres ', 'Pós, MBA, e título de especialista ',
#        'No momento não faço pós ', 'Nenhum ', 'Nao',
#        'Não realizei, ainda.'], dtype=object)

# %%
df['formacao_continuada'] = df['formacao_continuada'].replace(['Nenhum', 'Não ','Não estou estudando', 'No momento não faço pós ', 'Nenhum ',
                                                               'Nao','Não realizei, ainda.'], 'Não realizou formação continuada')
df['formacao_continuada'] = df['formacao_continuada'].replace(['Especialização','Pós-graduação em oncologia ','Pós, MBA, e título de especialista '], 'Especialização')
df['formacao_continuada'] = df['formacao_continuada'].replace([ 'Aperfeiçoamento/Aprimoramento/ Capacitação', 'Cursos livres '], 'Outras Formações')

# %%
df['motivo_pos_graduacao'].unique()
# Out:
# array(['Você achou necessário continuar estudando para completar a sua formação acadêmica',
#        'Não tive interesse em continuar',
#        'Não estou mais trabalhando na area', 'Não fiz ',
#        'Gosto de estudar',
#        'Você pretende ser ou é docente ou pesquisador',
#        'Por exigência do mercado de trabalho', 'Não estou estudando ',
#        'Falta de opção', 'Queria entrar em hospital ', 'Ainda não fiz ',
#        'Quero fazer Farmácia Clínica ', 'Não fiz', 'Nao', 'Não ', '. ',
#        'Não faço '], dtype=object)

# %%
df['motivo_pos_graduacao'] = df['motivo_pos_graduacao'].replace(['Não estou estudando ','Não tive interesse em continuar','Não estou mais trabalhando na area', 'Não fiz ',
                                                                 'Ainda não fiz ','Quero fazer Farmácia Clínica ', 'Não fiz', 'Nao', 'Não ', '. ',  'Não faço '],'Não realizou formação continuada')
df['motivo_pos_graduacao'] = df['motivo_pos_graduacao'].replace(['Você achou necessário continuar estudando para completar a sua formação acadêmica','Você pretende ser ou é docente ou pesquisador',
                                                                   'Por exigência do mercado de trabalho', 'Falta de opção', 'Queria entrar em hospital '], 'Necessidade de maior formação')
df['motivo_pos_graduacao'] = df['motivo_pos_graduacao'].replace(['Gosto de estudar'], 'Gosto por estudar')

# %%
df[ 'capacitacao_profissional_continua'].unique()
# Out:
# array(['mais de 1 a cada seis meses', 'não frequento', '1 a cada 6 meses',
#        '1 por ano',
#        'A empresa onde trabalho realiza encontros mensais para treinamentos farmacêuticos. ',
#        '1 a cada dois anos'], dtype=object)

# %%
df[ 'capacitacao_profissional_continua']= df[ 'capacitacao_profissional_continua'].replace(['mais de 1 a cada seis meses','A empresa onde trabalho realiza encontros mensais para treinamentos farmacêuticos. '], 'Mais de 1 a cada 6 meses')

# %%
df[ 'classificacao_satisfacao_academica'].unique()
# Out:
# array(['regular', 'ótima', 'boa'], dtype=object)

# %%
df['falhas_formacao'].unique()
# Out:
# array(['Faltaram disciplinas para habilitá-lo no mercado de trabalho',
#        'Estágio com pouco tempo para cada área',
#        'Aulas práticas deficientes, laboratórios e instalações deficientes',
#        'Faltou método de aula para alguns professores',
#        'Alguns professores não ensinaram direito',
#        'Você não se empenhou o suficiente',
#        'Alguns professores não dominavam o conteúdo das aulas'],
#       dtype=object)

# %%
df['falhas_formacao'] = df['falhas_formacao'].replace([ 'Aulas práticas deficientes, laboratórios e instalações deficientes', 'Faltaram disciplinas para habilitá-lo no mercado de trabalho'], 'Deficiencia na grade curricular')
df['falhas_formacao'] = df['falhas_formacao'].replace(['Estágio com pouco tempo para cada área'], 'Deficiência no tempo de estágio')
df['falhas_formacao'] = df['falhas_formacao'].replace(['Faltou método de aula para alguns professores', 'Alguns professores não ensinaram direito', 'Alguns professores não dominavam o conteúdo das aulas'], 'Deficiência do quatro Docente')
df['falhas_formacao'] = df['falhas_formacao'].replace([ 'Você não se empenhou o suficiente'], 'Falta de empenho do Discente')

# %%
df['satisfacao_emprego'].unique()
# Out:
# array(['Satisfeito', 'Muito satisfeito', 'Parcialmente satisfeito',
#        'Gostaria de mudar de atividade\xa0 profissional'], dtype=object)

# %%
df['satisfacao_emprego'] = df['satisfacao_emprego'].replace(['Gostaria de mudar de atividade\xa0 profissional'], 'Gostaria de mudar de atividade profissional')

# %%
df['pontos_fortes_FAPAR'].unique()
# Out:
# array(['gestão', 'políticas acadêmicas e currículo',
#        'desenvolvimento da IES', 'infra estrutura', 'planejamento da IES'],
#       dtype=object)

# %%
df['fragilidade_FAPAR'].unique()
# Out:
# array(['políticas acadêmicas e currículo', 'infra estrutura', 'gestão',
#        'planejamento da IES', 'desenvolvimento da IES'], dtype=object)

# %%
df['prob_indicacao'].unique()
# Out:
# array([ 9, 10,  6,  8,  3,  7,  5,  2])

# %%
df.columns
# Out:
# Index(['Sexo', 'idade', 'estado_civil', 'filhos', 'semestre_conclusao',
#        'associacao_sindicato', 'ocupacao', 'atuacao_area_formacao',
#        'vinculo_emprego', 'n_locais_emprego', 'local_atuacao', 'area_atuacao',
#        'jornada_trabalho', 'grau_sat_rendimento_bruto', 'grau_sat_trabalho',
#        'obtencao_primeiro_emprego', 'dificuldade_primeiro_emprego',
#        'atribuicao_dificuldade_primeiro_emprego', 'tempo_para_colocao_mercado',
#        'formacao_continuada', 'motivo_pos_graduacao',
#        'capacitacao_profissional_continua',
#        'classificacao_satisfacao_academica', 'falhas_formacao',
#        'satisfacao_emprego', 'pontos_fortes_FAPAR', 'fragilidade_FAPAR',
#        'prob_indicacao'],
#       dtype='object')

# %%
df.head()
# Out:
#         Sexo idade estado_civil filhos semestre_conclusao  \
# 0  Masculino    27     Solteiro      0   Segundo semestre
# 1  Masculino    35     Solteiro      0   Segundo semestre
# 2   Feminino    26     Solteiro      0   Segundo semestre
# 3   Feminino    27     Solteiro      0  Primeiro semestre
# 4   Feminino    31     Solteiro      0   Segundo semestre
#
#   associacao_sindicato                 ocupacao atuacao_area_formacao  \
# 0                  Sim  trabalhando e estudando       sim, totalmente
# 1                  Não              trabalhando                   não
# 2                  Não              trabalhando                   não
# 3                  Não              trabalhando       sim, totalmente
# 4                  Não              trabalhando       sim, totalmente
#
#   vinculo_emprego  n_locais_emprego  ... tempo_para_colocao_mercado  \
# 0    Proprietário                 1  ...                   Imediato
# ...

# %%
df.to_csv('G:/Meu Drive/Nilce/Egresso/EGRESSO_UNIDO_limpo.csv', sep=',', encoding='utf-8', index=False)

# %%
df_limpo = pd.read_csv("G:/Meu Drive/Nilce/Egresso/EGRESSO_UNIDO_limpo.csv",sep=',', encoding='utf-8')

# %%
df_limpo.head()
# Out:
#         Sexo  idade estado_civil  filhos semestre_conclusao  \
# 0  Masculino     27     Solteiro       0   Segundo semestre
# 1  Masculino     35     Solteiro       0   Segundo semestre
# 2   Feminino     26     Solteiro       0   Segundo semestre
# 3   Feminino     27     Solteiro       0  Primeiro semestre
# 4   Feminino     31     Solteiro       0   Segundo semestre
#
#   associacao_sindicato                 ocupacao atuacao_area_formacao  \
# 0                  Sim  trabalhando e estudando       sim, totalmente
# 1                  Não              trabalhando                   não
# 2                  Não              trabalhando                   não
# 3                  Não              trabalhando       sim, totalmente
# 4                  Não              trabalhando       sim, totalmente
#
#   vinculo_emprego  n_locais_emprego  ... tempo_para_colocao_mercado  \
# 0    Proprietário                 1  ...                   Imediato
# ...

# %% [markdown]
# ## Plotagem Dados

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
#Gráfico de torta para a variável Sexo
df_limpo['Sexo'].value_counts().plot.pie(autopct='%1.1f%%', colors=['pink', 'cyan'], shadow=True, startangle=140)
plt.title('Sexo dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#Gráfico de histograma para a variável idade unindo as idades por faixa etária
df_limpo['idade'].hist(bins=6, color='lightseagreen', alpha=0.7)
plt.title('Idade dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Idade',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Quantidade',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.show()

# %%
#gráfico de barras para a variável estado_civil
sns.countplot(x='estado_civil', data=df_limpo)
plt.title('Estado Civil dos Egressos', fontdict={'fontsize': 15, 'fontweight': 'bold'}) #fonte negrita e tamanho 15
 #fonte negrita e tamanho 12
plt.xlabel('Estado Civil', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold') 
plt.ylim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#Gráfico de barras para a variável filhos
sns.countplot(x='filhos', data=df_limpo, color='green')
plt.title('Quantidade de Filhos dos Egressos', fontdict={'fontsize': 15, 'fontweight': 'bold'}) #fonte negrita e tamanho 15
 #fonte negrita e tamanho 12
plt.xlabel('Quantidade de Filhos', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#gráfico de pizza para a variável semestre_conclusao
df_limpo['semestre_conclusao'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Semestre de Conclusão dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#Gráfico de pizza para a variável associacao_sindicato
df_limpo['associacao_sindicato'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140, colors=['orange', 'khaki'])
plt.title('Associação ao Sindicato dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#gŕafico de barras para a variável ocupacao
sns.countplot(y='ocupacao', data=df_limpo,color='dodgerblue')
plt.title('Ocupação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Ocupação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,50)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#Gráfico de pizza para a variável atuacao_area_formacao
df_limpo['atuacao_area_formacao'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Área de Atuação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#grafico de barras para a variável vinculo_emprego
sns.countplot(y='vinculo_emprego', data=df_limpo, color='olivedrab')
plt.title('Vínculo Empregatício dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Vínculo Empregatício', fontsize=12, fontweight='bold')
plt.xlabel('Total',     fontsize=12, fontweight='bold')
plt.xlim(0,50)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')

plt.show()

# %%
#grafico de barras para a variável n_locais_emprego
sns.countplot(x='n_locais_emprego', data=df_limpo)
plt.title('Número de Locais de Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Número de Locais de Emprego', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,50)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável local_atuacao
sns.countplot(y='local_atuacao', data=df_limpo)
plt.title('Local de Atuação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Local de Atuação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,30)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável area_atuacao
sns.countplot(y='area_atuacao', data=df_limpo)
plt.title('Área de Atuação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Área de Atuação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável jornada_trabalho
sns.countplot(x='jornada_trabalho', data=df_limpo,color='brown')
plt.title('Jornada de Trabalho dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Jornada de Trabalho em horas', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,45)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável grau_sat_rendimento_bruto
sns.countplot(y='grau_sat_rendimento_bruto', data=df_limpo)
plt.title('Grau de Satisfação com o Rendimento Bruto dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Grau de Satisfação com o Rendimento Bruto',fontdict={'fontsize': 11, 'fontweight': 'bold'})
plt.xlabel('Total', fontdict={'fontsize': 11, 'fontweight': 'bold'})
plt.xlim(0,30)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável grau_sat_trabalho
sns.countplot(y='grau_sat_trabalho', data=df_limpo,color='tomato')
plt.title('Grau de Satisfação com o Trabalho dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Grau de Satisfação com o Trabalho',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,40)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável obtencao_primeiro_emprego
sns.countplot(y='obtencao_primeiro_emprego', data=df_limpo)
plt.title('Obtenção do Primeiro Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Obtenção do Primeiro Emprego',fontdict={'fontsize': 11, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xticks(rotation=45)
plt.xlim(0,25)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável dificuldade_primeiro_emprego
sns.countplot(y='dificuldade_primeiro_emprego', data=df_limpo,color='rebeccapurple')
plt.title('Dificuldade para Obter o Primeiro Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Dificuldade do Primeiro Emprego',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,40)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#gráfico de barras horizontal para a variável atribuicao_dificuldade_primeiro_emprego
sns.countplot(y='atribuicao_dificuldade_primeiro_emprego', data=df_limpo, color='plum')
plt.title('Atribuição da Dificuldade para Obter o Primeiro Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total')
plt.ylabel('Atribuição da Dificuldade para Primeiro Emprego',fontdict={ 'fontweight': 'bold'})
plt.xlim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável tempo_para_colocao_mercado
sns.countplot(x='tempo_para_colocao_mercado', data=df_limpo,color='Darkmagenta')
plt.title('Tempo para Colocação no Mercado de Trabalho dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Tempo para Colocação no Mercado de Trabalho',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,45)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#gráfico horizontal de barras para a variável formacao_continuada
sns.countplot(y='formacao_continuada', data=df_limpo, color='navy')
plt.title('Formação Continuada dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Formação Continuada', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,30)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#gráfico de barras horizontal para a variável motivo_pos_graduacao
sns.countplot(y='motivo_pos_graduacao', data=df_limpo,color='coral')
plt.title('Motivo para Realizar Pós-Graduação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Motivo para Realizar Pós-Graduação',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,50)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras horizontal para a variável capacitacao_profissional_continua

sns.countplot(y='capacitacao_profissional_continua', data=df_limpo, color='darkorange')
plt.title('Capacitação Profissional Contínua dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Capacitação Profissional Contínua',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,30)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável classificacao_satisfacao_academica
sns.countplot(x='classificacao_satisfacao_academica', data=df_limpo,color='darkgreen')
plt.title('Classificação da Satisfação Acadêmica dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Classificação da Satisfação Acadêmica',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#gráfico de barras horizontal para a variável falhas_formacao
sns.countplot(y='falhas_formacao', data=df_limpo, color='crimson')
plt.title('Falhas na Formação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Falhas na Formação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
sns.countplot(y='satisfacao_emprego', data=df_limpo, color='olive')
plt.title('Satisfação no Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Satisfação no Emprego',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,35)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#Gráfico de pizza com labels dos pontos fortes da FAPAR

df_limpo['pontos_fortes_FAPAR'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Pontos Fortes da FAPAR',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#gráfico pizza com labels dos pontos fracos da FAPAR
df_limpo['fragilidade_FAPAR'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Fragilidades da FAPAR',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#grafico de barras para a variável prob_indicacao
sns.countplot(x='prob_indicacao', data=df_limpo,color='violet') 
plt.title('Probabilidade de Indicação da FAPAR para os Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Probabilidade de Indicação da FAPAR', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,25)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()
