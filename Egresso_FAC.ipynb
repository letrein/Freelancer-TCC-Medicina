# %%
import pandas as pd


# Leitura do arquivo CSV com tratamento de erros
df = pd.read_csv("G:/Meu Drive/Nilce/Egresso/EGRESSO FAC.csv", 
                 sep=',', encoding='utf-8')  

# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#         Sexo IDADE Qual seu estado civil?           Tem filhos?  \
# 0  Masculino    30                 Casado  Sim, 1 menino 4 anos
# 1  Masculino    36               Solteiro                   Sim
# 2   Feminino    27               Solteira                   Não
# 3  Masculino    59             Divorciado                     2
# 4  Masculino    34                 Casado                     4
#
#   Informe o semestre de conclusão da graduação?  \
# 0                               2 semestre 2017
# 1                            2 semestre de 2022
# 2                                       02/2022
# 3                                       12/2022
# 4                                        2/2017
#
#   Você é filiado a Associação/Sindicato de Classe?     Atualmente você está  \
# 0                                              Sim  trabalhando e estudando
# 1                                              Sim  trabalhando e estudando
# ...

# %%
print(df.columns)

# Ajustar os nomes das colunas
df.rename(columns={
    'IDADE': 'Idade',
    'Qual seu estado civil?': 'estado_civil',
    'Tem filhos?': 'filhos',
    'Informe o semestre de conclusão da graduação?': 'semestre_conclusao',
    'Você é filiado a Associação/Sindicato de Classe?': 'associacao_sindicato',
    'Atualmente você está': 'situacao_atual',
    'Se você não está trabalhando, a que você atribui esse fato?': 'motivo_nao_trabalho',
    'Você está trabalhando na área da graduação/ensino superior que você fez na FAPAR?': 'trabalha_area_formacao',
    'Qual é o seu vínculo empregatício?': 'vinculo_emprego',
    'Número de locais de trabalho?': 'n_locais_trabalho',
    'Local de atuação? Exemplo: escritório, consultório, Universidade, domiciliar, etc. Especificar?': 'local_atuacao',
    'Qual sua área de atuação?': 'area_atuacao',
    'Qual sua jornada de trabalho diária?': 'jornada_trabalho',
    'Qual a sua média de rendimentos bruta mensal? Fica entre?': 'rendimento_bruto',
    'Qual o seu grau de satisfação com o trabalho': 'satisfacao_trabalho',
    'INFORMAÇÕES SOBRE O PRIMEIRO EMPREGO!\n Como foi a conquista do primeiro emprego/trabalho?': 'conquista_primeiro_emprego',
    'INFORMAÇÕES SOBRE O PRIMEIRO EMPREGO!\n Quais as dificuldades encontradas para a conquista do primeiro emprego/trabalho?': 'dificuldades_primeiro_emprego',
    'A que você atribui as dificuldades enfrentadas no primeiro emprego ou trabalho?': 'atribuicao_dificuldades_primeiro_emprego',
    'Quanto tempo demorou para conseguir colocação no mercado de trabalho?': 'tempo_colocacao_mercado',
    'INFORMAÇÕES DE EDUCAÇÃO CONTINUADA\n  \n Você realizou ou realiza algum curso de pós-graduação? Qual?\n': 'curso_pos_graduacao',
    'Caso tenha feito algum desses cursos de Pós-Graduação, qual foi a razão?': 'razao_pos_graduacao',
    'Com qual frequência você participa de congressos científicos, seminários, oficinas ou qualquer outra modalidade de encontro profissional para capacitação e ou atualização em temas?': 'frequencia_capacitacao',
    'INFORMAÇÕES SOBRE SATISFAÇÃO COM A FORMAÇÃO ACADÊMICA E ATUAÇÃO PROFISSIONAL\n  \n Como você classifica sua formação acadêmica?': 'classificacao_formacao_academica',
    'Se você acha que houve falhas na sua formação acadêmica, devido a?': 'falhas_formacao_academica',
    'Em relação a sua profissão você se considera:': 'consideracao_profissao',
    'pontos fortes': 'pontos_fortes',
    'fragilidade': 'fragilidade',
    'Qual é a probabilidade de você nos recomendar a um amigo ou a um colega?': 'probabilidade_indicacao'
}, inplace=True)
# Out:
# Index(['Sexo', 'IDADE', 'Qual seu estado civil?', 'Tem filhos?',
#        'Informe o semestre de conclusão da graduação?',
#        'Você é filiado a Associação/Sindicato de Classe?',
#        'Atualmente você está',
#        'Se você não está trabalhando, a que você atribui esse fato?',
#        'Você está trabalhando na área da graduação/ensino superior que você fez na FAPAR?',
#        'Qual é o seu vínculo empregatício?', 'Número de locais de trabalho?',
#        'Local de atuação? Exemplo: escritório, consultório, Universidade, domiciliar, etc. Especificar?',
#        'Qual sua área de atuação?', 'Qual sua jornada de trabalho diária?',
#        'Qual a sua média de rendimentos bruta mensal? Fica entre?',
#        'Qual o seu grau de satisfação com o trabalho',
#        'INFORMAÇÕES SOBRE O PRIMEIRO EMPREGO!\n Como foi a conquista do primeiro emprego/trabalho?',
# ...

# %%
print(df.columns)
# Out:
# Index(['Sexo', 'Idade', 'estado_civil', 'filhos', 'semestre_conclusao',
#        'associacao_sindicato', 'situacao_atual', 'motivo_nao_trabalho',
#        'trabalha_area_formacao', 'vinculo_emprego', 'n_locais_trabalho',
#        'local_atuacao', 'area_atuacao', 'jornada_trabalho', 'rendimento_bruto',
#        'satisfacao_trabalho', 'conquista_primeiro_emprego',
#        'dificuldades_primeiro_emprego',
#        'atribuicao_dificuldades_primeiro_emprego', 'tempo_colocacao_mercado',
#        'Curso_Pos_Graduacao', 'razao_pos_graduacao', 'frequencia_capacitacao',
#        'classificacao_formacao_academica', 'falhas_formacao_academica',
#        'consideracao_profissao', 'pontos_fortes', 'fragilidade',
#        'probabilidade_indicacao'],
#       dtype='object')

# %% [markdown]
# Arrumando coluna 'Sexo'

# %%
df['Sexo'].unique()
# Out:
# array(['Masculino', 'Feminino', 'Femenino', 'FEMININO'], dtype=object)

# %%
df['Sexo'] = df['Sexo'].replace(['Femenino','FEMININO',], 'Feminino')

# %%
df['Sexo'].unique()
# Out:
# array(['Masculino', 'Feminino'], dtype=object)

# %% [markdown]
# Arrumando coluna "idade"

# %%
df['Idade'].unique()
# Out:
# array(['30', '36', '27', '59', '34', '32', '26', '63 anos', '25', '28',
#        '26 anos', '38 anos', '41 anos', '49 anos', '53', '54', '31', '60',
#        '44'], dtype=object)

# %%
df['Idade'] = df['Idade'].replace(['26 anos'], '26')
df['Idade'] = df['Idade'].replace(['38 anos'], '38')
df['Idade'] = df['Idade'].replace(['41 anos'], '41')
df['Idade'] = df['Idade'].replace(['49 anos'], '49')
df['Idade'] = df['Idade'].replace(['63 anos'], '63')

# %%
df['Idade'].unique()
# Out:
# array(['30', '36', '27', '59', '34', '32', '26', '63', '25', '28', '38',
#        '41', '49', '53', '54', '31', '60', '44'], dtype=object)

# %% [markdown]
# arrumando coluna "estado_civil"

# %%
df['estado_civil'].unique()
# Out:
# array(['Casado', 'Solteiro', 'Solteira', 'Divorciado', 'Casada',
#        'Divorciada', 'Convivente', 'solteira', 'viúva'], dtype=object)

# %%
df['estado_civil'] = df['estado_civil'].replace(['Solteira ','Solteira','Solteiro ', 'solteira'], 'Solteiro')
df['estado_civil'] = df['estado_civil'].replace(['Casada ','Casada','Casado ','casada','Cansada '], 'Casado')
df['estado_civil'] = df['estado_civil'].replace(['Divorciada','divorciada'], 'Divorciado')
df['estado_civil'] = df['estado_civil'].replace(['viúva'], 'Viúvo')
df['estado_civil'] = df['estado_civil'].replace(['Convivente'], 'União estável')

# %%
df['estado_civil'].unique()
# Out:
# array(['Casado', 'Solteiro', 'Divorciado', 'União estável', 'Viúvo'],
#       dtype=object)

# %% [markdown]
# arrumar coluna 'filhos'

# %%
df['filhos'].unique()
# Out:
# array(['Sim, 1 menino 4 anos', 'Sim', 'Não', '2', '4', 'Sim, dois', 'Nao',
#        'Sim 2', 'Sim, 03', 'sim', '1 filha'], dtype=object)

# %%
df['filhos'] = df['filhos'].replace(['Nao','Não'], '0')
df['filhos'] = df['filhos'].replace(['Sim, 1 menino 4 anos','sim','1 filha','Sim'], '1')
df['filhos'] = df['filhos'].replace(['Sim 2','Sim, dois'], '2')
df['filhos'] = df['filhos'].replace(['Sim, 03'] , '3')

# %%
df['filhos'].unique()
# Out:
# array(['1', '0', '2', '4', '3'], dtype=object)

# %% [markdown]
# arrumando coluna "semestre_conclusao"

# %%
df['semestre_conclusao'].unique()
# Out:
# array(['2 semestre 2017', '2 semestre de 2022', '02/2022', '12/2022',
#        '2/2017', '2º de 2022', 'Dezembro de 2022', '2/2020',
#        'Segundo semestre de 2022', '########', '2/2021', '02/2020',
#        'dez./2023', '2º/2020', '12/2020', 'Segundo', '2°/2023',
#        '02 se\n  Semestre de 2021', '2º 2023', '1/2024',
#        '1° semestre 2024'], dtype=object)

# %%
df['semestre_conclusao'] = df['semestre_conclusao'].replace(['2 semestre 2017','2 semestre de 2022','02/2022','02/2020','Segundo','2°/2023','12/2022', '2/2017','2º/2020', '2º de 2022', '12/2020','Dezembro de 2022','2/2020','Segundo semestre de 2022','2/2021', 'dez./2023','02 se\n  Semestre de 2021','2º 2023'], 'Segundo semestre')
df['semestre_conclusao'] = df['semestre_conclusao'].replace([ '########','02/2020','1/2024','1° semestre 2024'], 'Primeiro semestre')

# %%
df['semestre_conclusao'].unique()
# Out:
# array(['Segundo semestre', 'Primeiro semestre'], dtype=object)

# %% [markdown]
# Avaliação colunas

# %%
df['associacao_sindicato'].unique()
# Out:
# array(['Sim', 'Não'], dtype=object)

# %%
df['situacao_atual'].unique()
# Out:
# array(['trabalhando e estudando', 'desempregado', 'trabalhando',
#        'estudando'], dtype=object)

# %%
df['situacao_atual'] = df['situacao_atual'].replace(['OAB'], 'trabalhando')
df['situacao_atual'] = df['situacao_atual'].replace(['Aberto a contratos'], 'desempregado')

# %%
df['motivo_nao_trabalho'].unique()
# Out:
# array([nan, 'A minha formação', 'Sem resposta',
#        'Ao término do curso de Direito e aprovação no exame da OAB',
#        'Para cuidar do meu filho',
#        'A conclusão do curso e aprovação na OAB.', 'Faculdade',
#        'Sou estágiaria, mais para o mercado de trabalho está difícil, ainda mais sem aprovação na OAB.',
#        'Incompatibilidade com o meu serviço, segundo o código de ética',
#        'Estou trabalhando', 'não se aplica'], dtype=object)

# %%
df['motivo_nao_trabalho'] = df['motivo_nao_trabalho'].fillna('Trabalhando')

# %%
df['motivo_nao_trabalho'] = df['motivo_nao_trabalho'].replace(['Estou trabalhando', 'não se aplica','Empregado','Sem resposta'], 'Trabalhando')
df['motivo_nao_trabalho'] = df['motivo_nao_trabalho'].replace(['A minha formação', 'Incompatibilidade com o meu serviço, segundo o código de ética'], 'Formação Incompatível')
df['motivo_nao_trabalho'] = df['motivo_nao_trabalho'].replace(['Para cuidar do meu filho'], 'Motivos Pessoais')
df['motivo_nao_trabalho'] = df['motivo_nao_trabalho'].replace(['Sou estágiaria, mais para o mercado de trabalho está difícil, ainda mais sem aprovação na OAB.', 'A conclusão do curso e aprovação na OAB.','Ao término do curso de Direito e aprovação no exame da OAB','Faculdade' ], 'Estudando')

# %%
df['trabalha_area_formacao'].unique()
# Out:
# array(['sim, totalmente', 'não', 'sim, parcialmente'], dtype=object)

# %% [markdown]
# arrumando 'vinculo_empregado"

# %%
df['vinculo_emprego'].unique()
# Out:
# array(['Autônomo', 'CLT', 'Funcionário público', 'Desempregado',
#        'Contrato temporário', 'Estagiário'], dtype=object)

# %%
df['vinculo_emprego'] = df['vinculo_emprego'].replace(['Autônomo /prestador de serviço','Proprietário'], 'Autônomo')
df['vinculo_emprego'] = df['vinculo_emprego'].replace([ 'Empregado com carteira assinada meio período e autônomo no outro período','Empregado com carteira assinada','CLT e autonomo','Empregado com carteira assinada'] , 'CLT')
df['vinculo_emprego'] = df['vinculo_emprego'].replace([ 'Sem trabalho'] , 'Desempregado')
df['vinculo_emprego'] = df['vinculo_emprego'].replace(['Funcionário público concursado','Servidor público'] , 'Funcionário público')

# %%
df['vinculo_emprego'].unique()
# Out:
# array(['Autônomo', 'CLT', 'Funcionário público', 'Desempregado',
#        'Contrato temporário', 'Estagiário'], dtype=object)

# %%
print(df.columns)
# Out:
# Index(['Sexo', 'Idade', 'estado_civil', 'filhos', 'semestre_conclusao',
#        'associacao_sindicato', 'situacao_atual', 'motivo_nao_trabalho',
#        'trabalha_area_formacao', 'vinculo_emprego', 'n_locais_trabalho',
#        'local_atuacao', 'area_atuacao', 'jornada_trabalho', 'rendimento_bruto',
#        'satisfacao_trabalho', 'conquista_primeiro_emprego',
#        'dificuldades_primeiro_emprego',
#        'atribuicao_dificuldades_primeiro_emprego', 'tempo_colocacao_mercado',
#        'Curso_Pos_Graduacao', 'razao_pos_graduacao', 'frequencia_capacitacao',
#        'classificacao_formacao_academica', 'falhas_formacao_academica',
#        'consideracao_profissao', 'pontos_fortes', 'fragilidade',
#        'probabilidade_indicacao'],
#       dtype='object')

# %%
df['n_locais_trabalho'].unique()
# Out:
# array([1, 2])

# %%
df['local_atuacao'].unique()
# Out:
# array(['Escritório - Campo', 'Escritório e domiciliar', 'Prefeitura',
#        'Do miciliar', 'Escritório', 'Escritório de Advocacia',
#        'Sem trabalho', 'Tribunal Regional do Trabalho',
#        'Escritório domiciliar.', 'Residente técnico na Receita Estadual',
#        'Secretaria pública', 'Empresa de. Comunicação', 'Comércio',
#        'Não atuo', 'Órgão público', 'escritório', 'Domiciliar'],
#       dtype=object)

# %%
df['local_atuacao'] = df['local_atuacao'].replace(['Escritório - Campo','Escritório e domiciliar','Do miciliar','Empresa de. Comunicação','Escritório de Advocacia','Escritório domiciliar.', 'escritório','Domiciliar'] , 'Escritório')
df['local_atuacao'] = df['local_atuacao'].replace([ 'Sem trabalho', 'Não atuo','Não atuo na área'], 'Desempregado')
df['local_atuacao'] = df['local_atuacao'].replace([ 'Tribunal Regional do Trabalho', 'Prefeitura','Secretaria pública','Residente técnico na Receita Estadual','Servidor Publico'],  'Órgão público')

# %%
df['local_atuacao'].unique()
# Out:
# array(['Escritório', 'Órgão público', 'Desempregado', 'Comércio'],
#       dtype=object)

# %% [markdown]
# avaliação proximas colunas

# %%
df['area_atuacao'].unique()
# Out:
# array(['Engenharia Civil', 'Fiscalização', 'Telefonia móvel', 'Direito',
#        'Desempregado', 'Segurança', 'Fast Food', 'Educação'], dtype=object)

# %%
df['area_atuacao'] = df['area_atuacao'].replace(['Engenheiro Civil - Energia Renovaveis','Contrução, reformas',  'Projetos estruturais, escoramento, andaimes.'], 'Engenharia Civil')
df['area_atuacao'] = df['area_atuacao'].replace(['Advocacia Trabalhista', 'Analista Judiciário Oficial de Justiça Avaliador',  'Advocacia cível e trabalhista',  
                                                 'Coordenadora de Controladoria jurídica','Advogada','Direito Administrativo','Direito Previdenciário','Direito do Consumidor',
                                                'DIREITO DO CONSULMIDOR','Trabalhista e família' ], 'Direito')
df['area_atuacao'] = df['area_atuacao'].replace(['Sem trabalho','Não atuo'], 'Desempregado')
df['area_atuacao'] = df['area_atuacao'].replace(['Segurança Pública', 'Segurança do trabalho'], 'Segurança')

# %% [markdown]
# # CONTINUAR

# %%
df['jornada_trabalho'].unique()
# Out:
# array(['8', '12', '4', 'Desempregado', '6', '24 por 72h'], dtype=object)

# %%
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['8 horas','De 8 a 12 horas ', '44','07:20', '7h20'],'8')
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['De 8 a 12h',],'12')
df['jornada_trabalho'] = df['jornada_trabalho'].replace(['Sem trabalho','Não atuo'],'Desempregado')

# %%
df['rendimento_bruto'].unique()
# Out:
# array(['7 salários mínimos', '5 salários mínimos', '3 salários mínimos',
#        'mais de 8 salários mínimos', '2 salários mínimos',
#        '1 salário mínimo', '4 salários mínimos', 'Sem Renda'],
#       dtype=object)

# %%
df['rendimento_bruto'].fillna('Sem Renda', inplace=True)

# %%
#df['grau_sat_rendimento_bruto'] = df['grau_sat_rendimento_bruto'].replace(['\xa01 salário mínimo', 'Não informado','2 salários mínimos'], 'até 2 salários mínimos')
#df['grau_sat_rendimento_bruto'] = df['grau_sat_rendimento_bruto'].replace([ 'mais de 8 salários mínimos'], '8 salários mínimos ou mais')

# %%
df['satisfacao_trabalho'].unique()
# Out:
# array(['Muito satisfeito', 'Parcialmente satisfeito', 'Insatisfeito'],
#       dtype=object)

# %%
df['satisfacao_trabalho'] = df['satisfacao_trabalho'].replace(['Gostaria de mudar de atividade profissional'], 'Insatisfeito')

# %%
df['conquista_primeiro_emprego'].unique()
# Out:
# array(['Indicação', 'Entrevista de emprego', 'Contratação após estágio',
#        'Promoção para o cargo, já atuava na empresa em outro setor',
#        'Concurso Público', 'Desempregado'], dtype=object)

# %%
df['conquista_primeiro_emprego'] = df['conquista_primeiro_emprego'].replace(['Prova','Concurso'], 'Concurso Público')
df['conquista_primeiro_emprego'] = df['conquista_primeiro_emprego'].replace(['Estágio extra curricular'], 'Contratação após estágio')
df['conquista_primeiro_emprego'] = df['conquista_primeiro_emprego'].replace(['Determinação pessoal','Apresentação curricular', 'Promoção para o cargo, já atuava na empresa em outro setor' ], 'Entrevista de emprego')
df['conquista_primeiro_emprego'] = df['conquista_primeiro_emprego'].replace(['Não atuo na área', 'Não atuo'], 'Desempregado')

# %%
df['conquista_primeiro_emprego'].unique()
# Out:
# array(['Indicação', 'Entrevista de emprego', 'Contratação após estágio',
#        'Concurso Público', 'Desempregado'], dtype=object)

# %%
print(df.columns)
# Out:
# Index(['Sexo', 'Idade', 'estado_civil', 'filhos', 'semestre_conclusao',
#        'associacao_sindicato', 'situacao_atual', 'motivo_nao_trabalho',
#        'trabalha_area_formacao', 'vinculo_emprego', 'n_locais_trabalho',
#        'local_atuacao', 'area_atuacao', 'jornada_trabalho', 'rendimento_bruto',
#        'satisfacao_trabalho', 'conquista_primeiro_emprego',
#        'dificuldades_primeiro_emprego',
#        'atribuicao_dificuldades_primeiro_emprego', 'tempo_colocacao_mercado',
#        'Curso_Pos_Graduacao', 'razao_pos_graduacao', 'frequencia_capacitacao',
#        'classificacao_formacao_academica', 'falhas_formacao_academica',
#        'consideracao_profissao', 'pontos_fortes', 'fragilidade',
#        'probabilidade_indicacao'],
#       dtype='object')

# %%
df['dificuldades_primeiro_emprego'].unique()
# Out:
# array(['Salário baixo', 'Não houve dificuldade', 'Relações interpessoais',
#        'Obter Clientes', 'Desempregado'], dtype=object)

# %%
df['dificuldades_primeiro_emprego'] = df['dificuldades_primeiro_emprego'].replace(['Dificuldade para formação de sua clientela'], 'Obter Clientes')
df['dificuldades_primeiro_emprego'] = df['dificuldades_primeiro_emprego'].replace([ 'Encontrar emprego com salário compatível','Maior ganho'], 'Salário baixo')
df['dificuldades_primeiro_emprego'] = df['dificuldades_primeiro_emprego'].replace(['Oportunidade ', 'Dificuldade para formação de sua clientela'], 'Falta de Oportunidades')
df['dificuldades_primeiro_emprego'] = df['dificuldades_primeiro_emprego'].replace([ 'Não atuo já área','Não atuo'], 'Desempregado')

# %%
df['atribuicao_dificuldades_primeiro_emprego'].unique()
# Out:
# array(['Falta de reconhecimento', 'Falta de experiência',
#        'Falta de oportunidades',
#        'Falta de capacitação da formação acadêmica',
#        'Falta de reconhecimento da profissão pela sociedade',
#        'Desempregado', 'Não houve dificuldades'], dtype=object)

# %%
df['atribuicao_dificuldades_primeiro_emprego'] = df['atribuicao_dificuldades_primeiro_emprego'].replace(['Na época não tinha experiência, mas mesmo assim consegui atuar na área.'] , 'Falta de experiência')
df['atribuicao_dificuldades_primeiro_emprego'] = df['atribuicao_dificuldades_primeiro_emprego'].replace(['Falta de reconhecimento da profissão por outros profissionais', 'Dificuldade com crescimento na Espeesa'], 'Falta de reconhecimento')     
df['atribuicao_dificuldades_primeiro_emprego'] = df['atribuicao_dificuldades_primeiro_emprego'].replace(['Restrição do mercado de trabalho'], 'Falta de oportunidades')
df['atribuicao_dificuldades_primeiro_emprego'] = df['atribuicao_dificuldades_primeiro_emprego'].replace(['Falta de prática na faculdade, muita teoria prática insuficiente', 
                                                                                                  'Falta de capacitação científica',
                                                                                                  'Formação insatisfatória por parte da faculdade'],'Falta de capacitação da formação acadêmica')
df['atribuicao_dificuldades_primeiro_emprego'] = df['atribuicao_dificuldades_primeiro_emprego'].replace(['Não atuo'],'Desempregado')
df['atribuicao_dificuldades_primeiro_emprego'] = df['atribuicao_dificuldades_primeiro_emprego'].replace(['Não houve','Não houve'], 'Não houve dificuldades')

# %%
df['tempo_colocacao_mercado'].unique()
# Out:
# array(['de dois anos a cinco', 'Imediata', 'até 6 meses',
#        'de uma ano a dois', 'até um ano', 'Já estava no estágio atual',
#        'Desempregado'], dtype=object)

# %%
df['tempo_colocacao_mercado'] = df['tempo_colocacao_mercado'].replace(['Não atuo na área', 'Não atuo'], 'Desempregado')

# %%
df['Curso_Pos_Graduacao'].unique()
# Out:
# array(['Especialização', 'Aperfeiçoamento', 'Cursinho para OAB',
#        'Residência', 'Não realizou'], dtype=object)

# %%
df['Curso_Pos_Graduacao'] = df['Curso_Pos_Graduacao'].replace(['Aperfeiçoamento/Aprimoramento/ Capacitação'], 'Aperfeiçoamento')
df['Curso_Pos_Graduacao'] = df['Curso_Pos_Graduacao'].replace(['NÃO SE APLICA'], 'Não realizou')

# %%
df['razao_pos_graduacao'].unique()
# Out:
# array(['Complementar formação', 'Gosto de estudar',
#        'Por exigência do mercado de trabalho',
#        'Não realizou formação complementar', 'Ganhou Bolsa de estudo',
#        'Você pretende ser ou é docente ou pesquisador'], dtype=object)

# %%
df['razao_pos_graduacao'] = df['razao_pos_graduacao'].replace(['Falta de opção','Você achou necessário continuar estudando para completar a sua formação acadêmica'], 'Complementar formação')
df['razao_pos_graduacao'] = df['razao_pos_graduacao'].replace(['Não fiz pós', 'NÃO SE APLICA'], 'Não realizou formação complementar')
df['razao_pos_graduacao'] = df['razao_pos_graduacao'].replace([ 'Foi interessante em razão da bolsa de estudo'], 'Ganhou Bolsa de estudo')

# %%
df['frequencia_capacitacao'].unique()
# Out:
# array(['Não realiza capacitação complementar', 'acima de dois anos',
#        '1 por ano', '1 a cada 6 meses', '1 a cada dois anos'],
#       dtype=object)

# %%
df['frequencia_capacitacao'] = df['frequencia_capacitacao'].replace(['Tenho falta de tempo no momento', 'não frequento'], 'Não realiza capacitação complementar')

# %%
df['classificacao_formacao_academica'].unique()
# Out:
# array(['boa', 'regular', 'ótima'], dtype=object)

# %%
print(df.columns)
# Out:
# Index(['Sexo', 'Idade', 'estado_civil', 'filhos', 'semestre_conclusao',
#        'associacao_sindicato', 'situacao_atual', 'motivo_nao_trabalho',
#        'trabalha_area_formacao', 'vinculo_emprego', 'n_locais_trabalho',
#        'local_atuacao', 'area_atuacao', 'jornada_trabalho', 'rendimento_bruto',
#        'satisfacao_trabalho', 'conquista_primeiro_emprego',
#        'dificuldades_primeiro_emprego',
#        'atribuicao_dificuldades_primeiro_emprego', 'tempo_colocacao_mercado',
#        'Curso_Pos_Graduacao', 'razao_pos_graduacao', 'frequencia_capacitacao',
#        'classificacao_formacao_academica', 'falhas_formacao_academica',
#        'consideracao_profissao', 'pontos_fortes', 'fragilidade',
#        'probabilidade_indicacao'],
#       dtype='object')

# %%
df['falhas_formacao_academica'].unique()
# Out:
# array(['Você não se empenhou o suficiente',
#        'Curso de graduação insatisfatório', 'Professores insatisfatórios',
#        'Estágio insatisfatório'], dtype=object)

# %%
df['falhas_formacao_academica'] = df['falhas_formacao_academica'].replace([ 'Alguns professores não dominavam o conteúdo das aulas',
                                                                           'Alguns professores não ensinaram direito', 'Faltou método de aula para alguns professores'], 'Professores insatisfatórios')
df['falhas_formacao_academica'] = df['falhas_formacao_academica'].replace(['Faltaram disciplinas para habilitá-lo no mercado de trabalho', 
                                                                           'Aulas práticas deficientes, laboratórios e instalações deficientes'], 'Curso de graduação insatisfatório')
df['falhas_formacao_academica'] = df['falhas_formacao_academica'].replace(['Estágio com pouco tempo para cada área'], 'Estágio insatisfatório')

# %%
df['consideracao_profissao'].unique()
# Out:
# array(['Satisfeito', 'Muito satisfeito', 'Parcialmente satisfeito'],
#       dtype=object)

# %%
df['pontos_fortes'].unique()
# Out:
# array(['políticas acadêmicas e currículo', 'gestão', 'infra estrutura',
#        'desenvolvimento da IES', 'planejamento da IES'], dtype=object)

# %%
df['fragilidade'].unique()
# Out:
# array(['planejamento da IES', 'desenvolvimento da IES',
#        'políticas acadêmicas e currículo', 'infra estrutura', 'gestão'],
#       dtype=object)

# %%
df['probabilidade_indicacao'].unique()
# Out:
# array([ 8, 10,  7,  9,  5,  6])

# %%
df.columns
# Out:
# Index(['Sexo', 'Idade', 'estado_civil', 'filhos', 'semestre_conclusao',
#        'associacao_sindicato', 'situacao_atual', 'motivo_nao_trabalho',
#        'trabalha_area_formacao', 'vinculo_emprego', 'n_locais_trabalho',
#        'local_atuacao', 'area_atuacao', 'jornada_trabalho', 'rendimento_bruto',
#        'satisfacao_trabalho', 'conquista_primeiro_emprego',
#        'dificuldades_primeiro_emprego',
#        'atribuicao_dificuldades_primeiro_emprego', 'tempo_colocacao_mercado',
#        'Curso_Pos_Graduacao', 'razao_pos_graduacao', 'frequencia_capacitacao',
#        'classificacao_formacao_academica', 'falhas_formacao_academica',
#        'consideracao_profissao', 'pontos_fortes', 'fragilidade',
#        'probabilidade_indicacao'],
#       dtype='object')

# %%
df.head()
# Out:
#         Sexo idade estado_civil filhos semestre_conclusao  \
# 0  Masculino    27     Solteiro      0   Segundo semestre
# 1  Masculino    35     Solteiro      0   Segundo semestre
# 2   Feminino    26     Solteiro      0   Segundo semestre
# 3   Feminino    27     Solteiro      0  Primeiro semestre
# 4   Feminino    31     Solteiro      0   Segundo semestre
#
#   associacao_sindicato                 ocupacao atuacao_area_formacao  \
# 0                  Sim  trabalhando e estudando       sim, totalmente
# 1                  Não              trabalhando                   não
# 2                  Não              trabalhando                   não
# 3                  Não              trabalhando       sim, totalmente
# 4                  Não              trabalhando       sim, totalmente
#
#   vinculo_emprego  n_locais_emprego  ... tempo_para_colocao_mercado  \
# 0    Proprietário                 1  ...                   Imediato
# ...

# %%
df.to_csv('G:/Meu Drive/Nilce/Egresso/EGRESSO_FAC_limpo.csv', sep=',', encoding='utf-8', index=False)

# %%
df_limpo = pd.read_csv("G:/Meu Drive/Nilce/Egresso/EGRESSO_FAC_limpo.csv",sep=',', encoding='utf-8')

# %%
df_limpo.head()
# Out:
#         Sexo  Idade estado_civil  filhos semestre_conclusao  \
# 0  Masculino     30       Casado       1   Segundo semestre
# 1  Masculino     36     Solteiro       1   Segundo semestre
# 2   Feminino     27     Solteiro       0   Segundo semestre
# 3  Masculino     59   Divorciado       2   Segundo semestre
# 4  Masculino     34       Casado       4   Segundo semestre
#
#   associacao_sindicato           situacao_atual    motivo_nao_trabalho  \
# 0                  Sim  trabalhando e estudando            Trabalhando
# 1                  Sim  trabalhando e estudando            Trabalhando
# 2                  Sim  trabalhando e estudando  Formação Incompatível
# 3                  Sim             desempregado            Trabalhando
# 4                  Sim              trabalhando            Trabalhando
#
#   trabalha_area_formacao      vinculo_emprego  ...  tempo_colocacao_mercado  \
# 0        sim, totalmente             Autônomo  ...     de dois anos a cinco
# ...

# %% [markdown]
# ## Plotagem Dados

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
#Gráfico de torta para a variável Sexo
df_limpo['Sexo'].value_counts().plot.pie(autopct='%1.1f%%', colors=['pink', 'cyan'], shadow=True, startangle=140)
plt.title('Sexo dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#Gráfico de histograma para a variável idade unindo as idades por faixa etária
df_limpo['Idade'].hist(bins=6, alpha=0.7)
plt.title('Idade dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Idade',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Quantidade',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.show()

# %%
#gráfico de barras para a variável estado_civil
sns.countplot(x='estado_civil', data=df_limpo)
plt.title('Estado Civil dos Egressos', fontdict={'fontsize': 15, 'fontweight': 'bold'}) #fonte negrita e tamanho 15
 #fonte negrita e tamanho 12
plt.xlabel('Estado Civil', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold') 
plt.ylim(0,11)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#Gráfico de barras para a variável filhos
sns.countplot(x='filhos', data=df_limpo)
plt.title('Quantidade de Filhos dos Egressos', fontdict={'fontsize': 15, 'fontweight': 'bold'}) #fonte negrita e tamanho 15
 #fonte negrita e tamanho 12
plt.xlabel('Quantidade de Filhos', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,9)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#gráfico de pizza para a variável semestre_conclusao
df_limpo['semestre_conclusao'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Semestre de Conclusão dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#Gráfico de pizza para a variável associacao_sindicato
df_limpo['associacao_sindicato'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140, colors=['orange', 'khaki'])
plt.title('Associação ao Sindicato dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#gŕafico de barras para a variável ocupacao
sns.countplot(y='situacao_atual', data=df_limpo)
plt.title('Ocupação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Ocupação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,11.5)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#gráfico de barras para a variável motivo_nao_trabalho
sns.countplot(y='motivo_nao_trabalho', data=df_limpo)
plt.title('Motivo do Não Trabalho dos Egressos', fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.ylabel('Motivo', fontsize=12, fontweight='bold')
plt.xlim(0,16)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#Gráfico de pizza para a variável atuacao_area_formacao
df_limpo['trabalha_area_formacao'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Área de Atuação equivalente a Formação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#grafico de barras para a variável vinculo_emprego
sns.countplot(y='vinculo_emprego', data=df_limpo)
plt.title('Vínculo Empregatício dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Vínculo Empregatício', fontsize=12, fontweight='bold')
plt.xlabel('Total',     fontsize=12, fontweight='bold')
plt.xlim(0,11)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')

plt.show()

# %%
#grafico de barras para a variável n_locais_emprego
sns.countplot(x='n_locais_trabalho', data=df_limpo)
plt.title('Número de Locais de Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Número de Locais de Emprego', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,23)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável local_atuacao
sns.countplot(y='local_atuacao', data=df_limpo)
plt.title('Local de Atuação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Local de Atuação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,14)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável area_atuacao
sns.countplot(y='area_atuacao', data=df_limpo)
plt.title('Área de Atuação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Área de Atuação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,12)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável jornada_trabalho
sns.countplot(x='jornada_trabalho', data=df_limpo)
plt.title('Jornada de Trabalho dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Jornada de Trabalho em horas', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,11)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável grau_sat_rendimento_bruto
sns.countplot(y='rendimento_bruto', data=df_limpo)
plt.title('Renda bruta atual dos Egresso',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Número sálarios mínimo',fontdict={'fontsize': 11, 'fontweight': 'bold'})
plt.xlabel('Total', fontdict={'fontsize': 11, 'fontweight': 'bold'})
plt.xlim(0,6.5)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável grau_sat_trabalho
sns.countplot(y='satisfacao_trabalho', data=df_limpo)
plt.title('Grau de Satisfação Profissional dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Grau de Satisfação',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,14)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável obtencao_primeiro_emprego
sns.countplot(y='conquista_primeiro_emprego', data=df_limpo)
plt.title('Forma de Obtenção do Primeiro Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Meio de Obtenção',fontdict={'fontsize': 11, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,11)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável dificuldade_primeiro_emprego
sns.countplot(y='dificuldades_primeiro_emprego', data=df_limpo)
plt.title('Dificuldade para Obter o Primeiro Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Dificuldade do Primeiro Emprego',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,7.5)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#gráfico de barras horizontal para a variável atribuicao_dificuldade_primeiro_emprego
sns.countplot(y= 'dificuldades_primeiro_emprego', data=df_limpo)
plt.title('Atribuição da Dificuldade para Obter o Primeiro Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total')
plt.ylabel('Atribuição da Dificuldade',fontdict={ 'fontweight': 'bold'})
plt.xlim(0,7.5)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras horizontal para a variável tempo_para_colocao_mercado
sns.countplot(y='tempo_colocacao_mercado', data=df_limpo)
plt.title('Tempo para Colocação no Mercado de Trabalho dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total')
plt.ylabel('Tempo para Colocação' ,fontdict={ 'fontweight': 'bold'})
plt.xlim(0,13)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#gráfico horizontal de barras para a variável formacao_continuada
sns.countplot(y='Curso_Pos_Graduacao', data=df_limpo)
plt.title('Formação Continuada dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Formação Continuada', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,11)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#gráfico de barras horizontal para a variável motivo_pos_graduacao
sns.countplot(y='razao_pos_graduacao', data=df_limpo)
plt.title('Motivo para Realizar Pós-Graduação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Motivo para Realizar Pós-Graduação',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,13)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras horizontal para a variável capacitacao_profissional_continua

sns.countplot(y='frequencia_capacitacao', data=df_limpo)
plt.title('Frequência de Capacitação Profissional Contínua dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Frequência',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,13)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), ha='center', va='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#grafico de barras para a variável classificacao_satisfacao_academica
sns.countplot(x='classificacao_formacao_academica', data=df_limpo)
plt.title('Classificação da Satisfação Acadêmica dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Classificação da Satisfação Acadêmica',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylim(0,15)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %%
#gráfico de barras horizontal para a variável falhas_formacao
sns.countplot(y='falhas_formacao_academica', data=df_limpo)
plt.title('Falhas na Formação dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('Falhas na Formação', fontsize=12, fontweight='bold')
plt.xlabel('Total', fontsize=12, fontweight='bold')
plt.xlim(0,12)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
sns.countplot(y='consideracao_profissao', data=df_limpo)
plt.title('Satisfação no Emprego dos Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Total',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.ylabel('Nível de Satisfação',fontdict={'fontsize': 12, 'fontweight': 'bold'})
plt.xlim(0,10)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), va='center', ha='center', xytext=(10, 0), textcoords='offset points')
plt.show()

# %%
#Gráfico de pizza com labels dos pontos fortes da FAC

df_limpo['pontos_fortes'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Pontos Fortes da FAC',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#gráfico pizza com labels dos pontos fracos da FAC
df_limpo['fragilidade'].value_counts().plot.pie(autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Fragilidades da FAC',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.ylabel('')
plt.show()

# %%
#grafico de barras para a variável prob_indicacao
sns.countplot(x='probabilidade_indicacao', data=df_limpo) 
plt.title('Probabilidade de Indicação da FAC para os Egressos',fontdict={'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Probabilidade de Indicação da FAC', fontsize=12, fontweight='bold')
plt.ylabel('Total', fontsize=12, fontweight='bold')
plt.ylim(0,5.5)
for p in plt.gca().patches:
    plt.gca().annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()
