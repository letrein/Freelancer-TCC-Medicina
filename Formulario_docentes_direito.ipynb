# %% [markdown]
# ## Sobre os dados:

# %% [markdown]
# Os dados são oriundos de um questionário de uma unioversidade sobre os professores do curso de graduacao

# %% [markdown]
# ## Colunas

# %% [markdown]
# As colunas possuem como nome uma palavra chave para as seguintes questões:
#
#
# a) O professor apresentou e cumpriu o plano de ensino apresentado em sala de aula.
# b) O professor demonstrou domínio dos conteúdos.
# c) O professor trouxe o conteúdo para exemplos da realidade do aluno com o objetivo de simplificar o aprendizado
# d) O professor utilizou recursos (quadros, Datashow, cartazes, textos, instrumentos de acordo com a disciplina: modelos, tubo de ensaio, microscópio) e procedimentos didáticos adequados.
# e) O professor trabalhou com clareza e objetividade.
# f) O professor disponibilizou tempo para atender os discentes em sala de aula ou fora da sala de aula, pessoalmente e/ou à distância.
# g) O professor foi assíduo e pontual.
# h) O professor realizou avaliações compatíveis com o que foi trabalhado nas aulas.
# i) O professor analisou com os discentes os resultados das avaliações, fez a devolutiva.
# j) O professor manteve atitudes de respeito e cortesia.

# %% [markdown]
# # ANÁLISE DOS DADOS

# %%
import pandas as pd

curso = "Direito"
caminho = "H:/Meu Drive/Nilce/Direito/form_docentes_direito.csv"
# Leitura do arquivo CSV com tratamento de erros
df = pd.read_csv(caminho, 
                 sep=',', encoding='utf-8')  
# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#                 DOCENTE DISCIPLINA  \
# 0  André Luiz A Mansur        BCAP
# 1  André Luiz A Mansur        BCAP
# 2  André Luiz A Mansur     DIR HUM
# 3  André Luiz A Mansur     DIR HUM
# 4  André Luiz A Mansur     DIR HUM
#
#                                 Plano de ensino  \
# 0           concordo plenamente Score: 4,1 - 5
# 1           concordo plenamente Score: 4,1 - 5
# 2           concordo plenamente Score: 4,1 - 5
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                                Dominio conteudo  \
# 0           concordo plenamente Score: 4,1 - 5
# 1           concordo plenamente Score: 4,1 - 5
# 2           concordo plenamente Score: 4,1 - 5
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                           Exemplos da realidade  \
# 0           concordo plenamente Score: 4,1 - 5
# 1           concordo plenamente Score: 4,1 - 5
# 2           concordo plenamente Score: 4,1 - 5
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                             Recursos e didatica  \
# 0           concordo plenamente Score: 4,1 - 5
# 1           concordo plenamente Score: 4,1 - 5
# 2           concordo plenamente Score: 4,1 - 5
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                   Clareza e objetividade  \
# 0    concordo plenamente Score: 4,1 - 5
# 1    concordo plenamente Score: 4,1 - 5
# 2  concordo parcialmente  Score: 3,1 - 4
# 3    concordo plenamente Score: 4,1 - 5
# 4   discordo parcialmente  Score: 1,1- 2
#
#                           Atender aos discentes  \
# 0  nem concordo e nem discordo Score: 2,1 -  3
# 1           concordo plenamente Score: 4,1 - 5
# 2           concordo plenamente Score: 4,1 - 5
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                       Assíduo e pontual  \
# 0  discordo parcialmente  Score: 1,1- 2
# 1   concordo plenamente Score: 4,1 - 5
# 2   concordo plenamente Score: 4,1 - 5
# 3   concordo plenamente Score: 4,1 - 5
# 4  discordo parcialmente  Score: 1,1- 2
#
#                          Avaliacoes compativeis  \
# 0           concordo plenamente Score: 4,1 - 5
# 1           concordo plenamente Score: 4,1 - 5
# 2         concordo parcialmente  Score: 3,1 - 4
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                                      Devolutiva  \
# 0           concordo plenamente Score: 4,1 - 5
# 1           concordo plenamente Score: 4,1 - 5
# 2           concordo plenamente Score: 4,1 - 5
# 3           concordo plenamente Score: 4,1 - 5
# 4  nem concordo e nem discordo Score: 2,1 -  3
#
#                             Respeito e cortesia  Grau satisfacao docente
# 0           concordo plenamente Score: 4,1 - 5                         5
# 1           concordo plenamente Score: 4,1 - 5                         5
# 2           concordo plenamente Score: 4,1 - 5                         5
# 3           concordo plenamente Score: 4,1 - 5                         5
# 4  nem concordo e nem discordo Score: 2,1 -  3                         2

# %% [markdown]
# ## Arrumando variáveis de string para numérico

# %%
df['Plano de ensino'].unique()
# Out:
# array(['concordo plenamente Score: 4,1 - 5\xa0',
#        'nem concordo e nem discordo Score: 2,1 -\xa0 3\xa0',
#        'discordo parcialmente\xa0 Score: 1,1- 2',
#        'concordo parcialmente\xa0 Score: 3,1 - 4'], dtype=object)

# %%
replace_map = {
    'concordo plenamente Score: 4,1 - 5\xa0': 5,
    'concordo parcialmente\xa0 Score: 3,1 - 4': 4,
    'nem concordo e nem discordo Score: 2,1 -\xa0 3\xa0': 3,
   'discordo parcialmente\xa0 Score: 1,1- 2': 2,
   'discordo totalmente , Score: 0-1': 1,
    'não sei opinar': 0
}

df.replace(replace_map, inplace=True)
# Out:
# C:\Users\chii\AppData\Local\Temp\ipykernel_6624\318098381.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(replace_map, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of                        DOCENTE  DISCIPLINA  Plano de ensino  Dominio conteudo  \
# 0         André Luiz A Mansur         BCAP                5                 5
# 1         André Luiz A Mansur         BCAP                5                 5
# 2         André Luiz A Mansur      DIR HUM                5                 5
# 3         André Luiz A Mansur      DIR HUM                5                 5
# 4         André Luiz A Mansur      DIR HUM                3                 3
# 5         André Luiz A Mansur      DIR HUM                5                 5
# 6         André Luiz A Mansur      DIR HUM                2                 4
# 7         André Luiz A Mansur      DIR HUM                5                 5
# 8         André Luiz A Mansur      DIR HUM                3                 2
# 9         André Luiz A Mansur      DIR HUM                5                 5
# 10        André Luiz A Mansur      DIR HUM                5                 5
# 11        André Luiz A Mansur   CONT CONST                5                 5
# 12        André Luiz A Mansur   CONT CONST                5                 5
# 13     Luiz A da Silveira Dias        TGDC                5                 5
# 14     Luiz A da Silveira Dias        TGDC                5                 5
# 15     Luiz A da Silveira Dias        TGDC                5                 5
# 16     Luiz A da Silveira Dias        TGDC                5                 5
# 17     Luiz A da Silveira Dias        TGDC                5                 5
# 18     Luiz A da Silveira Dias        TGDC                5                 5
# 19     Luiz A da Silveira Dias        TGDC                5                 5
# 20     Luiz A da Silveira Dias        TGDC                5                 5
# 21     Luiz A da Silveira Dias        TGDC                5                 5
# 22     Luiz A da Silveira Dias         TGO                5                 5
# 23     Luiz A da Silveira Dias         TGO                5                 5
# 24   Victor C R da Silva Costa         TGC                5                 5
# 25   Victor C R da Silva Costa         TGC                5                 5
# 26   Victor C R da Silva Costa         TGC                5                 5
# 27   Victor C R da Silva Costa         TGC                5                 4
# 28   Victor C R da Silva Costa         TGC                3                 5
# 29   Victor C R da Silva Costa         TGC                5                 5
# 30   Victor C R da Silva Costa         TGC                4                 4
# 31   Victor C R da Silva Costa         TGC                5                 5
# 32   Victor C R da Silva Costa         TGC                4                 4
# 33     Luiz A da Silveira Dias    TIT CRED                5                 4
# 34     Luiz A da Silveira Dias    TIT CRED                5                 5
#
#     Exemplos da realidade  Recursos e didatica  Clareza e objetividade  \
# 0                       5                    5                       5
# 1                       5                    5                       5
# 2                       5                    5                       4
# 3                       5                    5                       5
# 4                       3                    3                       2
# 5                       4                    5                       4
# 6                       4                    2                       1
# 7                       5                    5                       5
# 8                       2                    1                       3
# 9                       4                    5                       5
# 10                      5                    5                       5
# 11                      5                    5                       5
# 12                      5                    5                       5
# 13                      5                    5                       5
# 14                      5                    5                       5
# 15                      5                    5                       5
# 16                      5                    4                       5
# 17                      5                    5                       5
# 18                      5                    5                       5
# 19                      5                    5                       5
# 20                      5                    5                       5
# 21                      5                    5                       5
# 22                      5                    5                       5
# 23                      5                    5                       5
# 24                      5                    5                       5
# 25                      5                    5                       5
# 26                      5                    5                       5
# 27                      5                    3                       4
# 28                      5                    2                       2
# 29                      5                    5                       5
# 30                      3                    4                       3
# 31                      5                    4                       5
# 32                      4                    5                       4
# 33                      5                    5                       5
# 34                      5                    5                       5
#
#     Atender aos discentes  Assíduo e pontual  Avaliacoes compativeis  \
# 0                       3                  2                       5
# 1                       5                  5                       5
# 2                       5                  5                       4
# 3                       5                  5                       5
# 4                       3                  2                       3
# 5                       5                  5                       4
# 6                       2                  5                       1
# 7                       5                  5                       5
# 8                       1                  2                       2
# 9                       5                  5                       5
# 10                      5                  5                       5
# 11                      3                  2                       5
# 12                      5                  5                       5
# 13                      5                  5                       5
# 14                      5                  5                       5
# 15                      5                  5                       5
# 16                      5                  5                       5
# 17                      5                  5                       5
# 18                      5                  5                       5
# 19                      5                  5                       5
# 20                      5                  5                       5
# 21                      5                  5                       5
# 22                      5                  5                       5
# 23                      5                  5                       5
# 24                      5                  5                       5
# 25                      5                  5                       5
# 26                      5                  5                       5
# 27                      5                  5                       5
# 28                      3                  5                       5
# 29                      5                  5                       5
# 30                      3                  4                       4
# 31                      5                  5                       5
# 32                      4                  4                       4
# 33                      3                  5                       5
# 34                      5                  5                       5
#
#     Devolutiva  Respeito e cortesia  Grau satisfacao docente
# 0            5                    5                        5
# 1            5                    5                        5
# 2            5                    5                        5
# 3            5                    5                        5
# 4            3                    3                        2
# 5            5                    4                        4
# 6            3                    1                        2
# 7            5                    5                        5
# 8            4                    2                        2
# 9            5                    5                        5
# 10           5                    5                        5
# 11           5                    5                        5
# 12           5                    5                        5
# 13           5                    5                        5
# 14           5                    5                        5
# 15           5                    5                        5
# 16           5                    5                        5
# 17           5                    5                        5
# 18           5                    5                        5
# 19           5                    5                        5
# 20           5                    5                        5
# 21           5                    5                        5
# 22           5                    5                        4
# 23           5                    5                        5
# 24           5                    5                        5
# 25           5                    5                        5
# 26           5                    5                        5
# 27           5                    5                        4
# 28           5                    5                        4
# 29           5                    5                        5
# 30           3                    4                        4
# 31           5                    5                        5
# 32           4                    4                        4
# 33           5                    5                        5
# 34           5                    5                        5  >

# %%
# Salvar o novo dataframe com o nome semelhante ao original, acrescido de '_numerico'
caminho_novo = "H:/Meu Drive/Nilce/Direito/form_docentes_direito_numerico.csv"
df.to_csv(caminho_novo, index=False)

# %%
df_professores = pd.read_csv(caminho_novo)
df_professores.head()
# Out:
#                 DOCENTE DISCIPLINA  Plano de ensino  Dominio conteudo  \
# 0  André Luiz A Mansur        BCAP                5                 5
# 1  André Luiz A Mansur        BCAP                5                 5
# 2  André Luiz A Mansur     DIR HUM                5                 5
# 3  André Luiz A Mansur     DIR HUM                5                 5
# 4  André Luiz A Mansur     DIR HUM                3                 3
#
#    Exemplos da realidade  Recursos e didatica  Clareza e objetividade  \
# 0                      5                    5                       5
# 1                      5                    5                       5
# 2                      5                    5                       4
# 3                      5                    5                       5
# 4                      3                    3                       2
#
#    Atender aos discentes  Assíduo e pontual  Avaliacoes compativeis  \
# 0                      3                  2                       5
# 1                      5                  5                       5
# 2                      5                  5                       4
# 3                      5                  5                       5
# 4                      3                  2                       3
#
#    Devolutiva  Respeito e cortesia  Grau satisfacao docente
# 0           5                    5                        5
# 1           5                    5                        5
# 2           5                    5                        5
# 3           5                    5                        5
# 4           3                    3                        2

# %% [markdown]
# ## Plotagem de gráficos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
   
for professor in df_professores['DOCENTE'].unique():
    df_professor = df_professores[df_professores['DOCENTE'] == professor]
    df_professor_mean = df_professor.mean(numeric_only=True)
    
    plt.figure(figsize=(7, 5))
    sns.barplot(y=df_professor_mean.index, x=df_professor_mean.values, palette="pastel")
    plt.title(f"Média das Avaliações - {professor}")
    plt.ylabel("Critérios de Avaliação")
    plt.xlabel("Média")
    plt.xlim(0, 5.5)
    #adicionando valor total de avaliações no gráfico
    for i, v in enumerate(df_professor_mean.values):
        plt.text(v, i, str(round(v, 2)), color='black', ha="left")
    plt.show()
# Out:
# C:\Users\chii\AppData\Local\Temp\ipykernel_6624\3396927315.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_professor_mean.index, x=df_professor_mean.values, palette="pastel")
# C:\Users\chii\AppData\Local\Temp\ipykernel_6624\3396927315.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_professor_mean.index, x=df_professor_mean.values, palette="pastel")
# C:\Users\chii\AppData\Local\Temp\ipykernel_6624\3396927315.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_professor_mean.index, x=df_professor_mean.values, palette="pastel")

# %%
# Agrupar os dados por professor e calcular as médias das avaliações
df_professores_grouped = df_professores.groupby('DOCENTE').mean(numeric_only=True).reset_index()

# Exibir as primeiras linhas
df_professores_grouped.head()
# Out:
#                       DOCENTE  Plano de ensino  Dominio conteudo  \
# 0   Victor C R da Silva Costa         4.555556          4.666667
# 1        André Luiz A Mansur          4.461538          4.538462
# 2     Luiz A da Silveira Dias         5.000000          4.923077
#
#    Exemplos da realidade  Recursos e didatica  Clareza e objetividade  \
# 0               4.666667             4.222222                4.222222
# 1               4.384615             4.307692                4.153846
# 2               5.000000             4.923077                5.000000
#
#    Atender aos discentes  Assíduo e pontual  Avaliacoes compativeis  \
# 0               4.444444           4.777778                4.777778
# 1               4.000000           4.076923                4.153846
# 2               4.846154           5.000000                5.000000
#
#    Devolutiva  Respeito e cortesia  Grau satisfacao docente
# 0    4.666667             4.777778                 4.555556
# 1    4.615385             4.230769                 4.230769
# 2    5.000000             5.000000                 4.923077

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_professores_grouped.set_index('DOCENTE').T, annot=True, cmap="viridis", fmt=".1f")
plt.title("Mapa de Calor das Avaliações por Professor")
plt.xlabel("Professor")
plt.ylabel("Critérios de Avaliação")
plt.show()

# %%
df_means = df_professores.groupby('DOCENTE').mean(numeric_only=True)
df_means.T.plot(kind='bar', figsize=(15, 6), colormap='tab20')
plt.title("Comparação de Avaliações por Professor")
plt.ylabel("Pontuação Média")
plt.xlabel("Critérios de Avaliação")
plt.xticks(rotation=20)
plt.legend(title="Professores", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
